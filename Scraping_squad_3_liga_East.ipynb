# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

urls = ["https://sportnet.sme.sk/futbalnet/k/msk-tesla-stropkov/tim/56345/hraci/?partId=&sutaz=6477ac257b634444d118634a",
        "https://sportnet.sme.sk/futbalnet/k/stara-lubovna-redfox-football-club/tim/58861/hraci/?sutaz=4408", 
        "https://sportnet.sme.sk/futbalnet/k/sk-odeva-lipany/tim/56404/hraci/?partId=&sutaz=6477ac257b634444d118634a",
        "https://sportnet.sme.sk/futbalnet/k/mfk-snina/tim/57733/hraci/?partId=&sutaz=6477ac257b634444d118634a",
        "https://sportnet.sme.sk/futbalnet/k/mfk-vranov-nad-toplou/tim/56129/hraci/?partId=&sutaz=6477ac257b634444d118634a",
        "https://sportnet.sme.sk/futbalnet/k/slavia-tu-kosice/tim/59071/hraci/?partId=&sutaz=6477ac257b634444d118634a",
        "https://sportnet.sme.sk/futbalnet/k/ftc-filakovo/tim/59041/hraci/?partId=&sutaz=6477ac257b634444d118634a",
        "https://sportnet.sme.sk/futbalnet/k/msk-rimavska-sobota/tim/56899/hraci/?partId=&sutaz=6477ac257b634444d118634a",
        "https://sportnet.sme.sk/futbalnet/k/msk-namestovo/tim/58967/hraci/?partId=&sutaz=6477ac257b634444d118634a",
        "https://sportnet.sme.sk/futbalnet/k/msk-novohrad-lucenec/tim/56578/hraci/?partId=&sutaz=6477ac257b634444d118634a",
        "https://sportnet.sme.sk/futbalnet/k/msk-spisske-podhradie/tim/57153/",
        "https://sportnet.sme.sk/futbalnet/k/tj-tatran-oravske-vesele/tim/59288/hraci/?partId=&sutaz=6477ac257b634444d118634a",
        "https://sportnet.sme.sk/futbalnet/k/tj-banik-kalinovo/tim/58424/hraci/?partId=&sutaz=6477ac257b634444d118634a",
        "https://sportnet.sme.sk/futbalnet/k/partizan-bardejov-bsk/tim/56183/hraci/?partId=&sutaz=6477ac257b634444d118634a",
        "https://sportnet.sme.sk/futbalnet/k/1fk-svidnik/tim/56502/hraci/?partId=&sutaz=6477ac257b634444d118634a"
      ]
print(len(urls))

all_players = []
all_statistics = []
all_goals = []
all_red = []
all_yellow = []
team_list = []

for url in urls:
    # Send a request to the webpage
    response = requests.get(url)
    #print(response)
    respo.append(response)
    #print(respo)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Parse the webpage content
        soup = BeautifulSoup(response.text, 'html.parser')
        #print(soup)
    
        team = soup.find('h1', class_='sc-fSnZTl fWUFUp').text
   

        a_elements = soup.find_all('a', class_='sc-chbAZy cYGgBV')
        
        PlayersList = [x.get_text().strip() for x in a_elements]
        print(len(PlayersList))
        if team:
            for x in range(0, len(PlayersList)):
                #print(team)
                team_list.append(team)
        #print(team)
        all_players.extend(PlayersList)

        
        #players = [player.get_text() for player in a_elements]
        #print(players)
    
        # Find all <td> elements with the specific class
        td_elements = soup.find_all('td', class_='sc-jVKKMF sc-gAmKBr iaisEp jddbPB')
        
        AllStats = [x.get_text() for x in td_elements]
        all_statistics.extend(AllStats)
        
        AllGoals = [x.get_text() for x in td_elements[0::3]]
        all_goals.extend(AllGoals)
        
        YellowCards = [x.get_text() for x in td_elements[1::3]]
        all_yellow.extend(YellowCards)
        
        RedCards = [x.get_text() for x in td_elements[2::3]]
        all_red.extend(RedCards)
        
        AllTeams = [x for x in team]
        #print(AllTeams)
        #team_list.append(AllTeams)
        
        # Extract and print the numbers
        #numbers = [td.get_text() for td in td_elements]
        #print(team)
    else:
        print("Failed to retrieve the webpage")

#print(all_players)
#print(len(team_list))
#print(all_statistics)
#print(all_statistics)
df = pd.DataFrame({"Name": all_players, "Goals": all_goals, "Yellow cards": all_yellow, "Red cards": all_red, "Team": team_list})
print(df)

df.to_csv("3_liga_east_2023_24_squad.csv", encoding='utf-8-sig', index=False)    
#print(df)
# Out:
# 15
# 34
# 25
# 25
# 30
# 29
# 40
# 25
# 38
# 28
# 30
# 0
# 40
# 56
# 38
# 43
#                   Name Goals Yellow cards Red cards                Team
# 0         Dušan Dlugoš     0            1         0  MŠK Tesla Stropkov
# 1         Samuel Seman     0            0         0  MŠK Tesla Stropkov
# 2           Filip Špak     1            4         1  MŠK Tesla Stropkov
# 3    Miroslav Keresteš     4            4         0  MŠK Tesla Stropkov
# 4       Marek Matkobiš     0            6         0  MŠK Tesla Stropkov
# ..                 ...   ...          ...       ...                 ...
# 476         Roman Bush     0            0         0        1.FK Svidník
# 477      Oliver Reiter     8            1         0        1.FK Svidník
# 478       Tomáš Klučár     1            5         1        1.FK Svidník
# 479  Oleksandr Voitiuk     3            4         0        1.FK Svidník
# 480        Tibor Rogoš     0            0         0        1.FK Svidník
#
# [481 rows x 5 columns]
